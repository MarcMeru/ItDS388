# %%
# %%capture

# !pip install ffn
# !pip install --upgrade pandas_datareader

# %%
import ffn

df = ffn.get("2330.tw, ^twii", start = "2020-1-1")
df.head()
# Out:
#                 2330tw          twii
# Date
# 2020-01-02  313.791626  12100.480469
# 2020-01-03  314.254456  12110.429688
# 2020-01-06  307.312195  11953.360352
# 2020-01-07  304.998047  11880.320312
# 2020-01-08  304.998047  11817.099609

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

fig, ax = plt.subplots(figsize = (12, 6))
ax.plot(df["2330tw"])
ax.set_ylabel("Price")
ax.grid(True)

ax2 = ax.twinx()
ax2.plot(df["twii"], color = "red")
ax2.set_ylabel("Index")
# Out:
# Text(0, 0.5, 'Index')

# %%
df2 = df.pct_change()
df2.hist(figsize = (10, 5), bins = 40)
# Out:
# array([[<Axes: title={'center': '2330tw'}>,
#         <Axes: title={'center': 'twii'}>]], dtype=object)

# %%
df2.corr()
# Out:
#          2330tw     twii
# 2330tw  1.00000  0.85375
# twii    0.85375  1.00000

# %%
df2.plot.scatter(x = "2330tw", y = "twii", figsize = (6, 6), grid = True)
plt.title("Correlation of Return Rates = {0}".format(round(df2.corr().values[0, 1], 2)))
# Out:
# Text(0.5, 1.0, 'Correlation of Return Rates = 0.85')
